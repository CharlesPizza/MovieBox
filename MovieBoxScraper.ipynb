# %%
import re
import requests
import lxml
import pandas as pd
import time
import numpy as np
from random import randint
from bs4 import BeautifulSoup as bs

# %%
class WeeklyCharts():
  def __init__(self, stop):
    self.prefix = 'https://www.boxofficemojo.com/weekly/'
    self.date = 2020.00
    self.stop = stop
    self.string_url = ''
    self.movie_dict = {}
    self.string_sfx = ''
    self.final_df = pd.DataFrame()

  def string_suff(self):
    # URL suffix format is a 2 digit year, W, 2 digit week; starting at 20W01
    # Weeks start on friday. Converted to a float for ease of calculations
    string_sfx = str('{:.2f}'.format(self.date))
    string_sfx = string_sfx.replace('.','W')
    self.string_sfx = string_sfx
    return (string_sfx + '/')

  def next_page(self):
    if self.date == self.stop:
      return (self.stop)
    elif round(self.date % 1, ndigits=2) == 0.52:
      self.date += 1
      self.date -= 0.51
    else:
      self.date += .01
    self.string_url = self.prefix + self.string_suff()
    return self.string_url

  def crawl(self):
    while self.date < self.stop:
      time.sleep(randint(1, 3))
      page = requests.get(self.next_page(), headers=header)
      soup = bs(page.text, 'lxml')

      table = soup.table.children
      for i in table:
        movie_name = i.find('a').text
        movie_url = i.find('a')['href']
        if movie_name not in self.movie_dict.keys():
          self.movie_dict[movie_name] = movie_url

      df = pd.read_html(page.text)
      df = df[0]
      df['YRWK'] = '{:2f}'.format(self.date)
      self.final_df = pd.concat([self.final_df, df])
      
  def save_final_df(self):
    self.final_df.to_csv(f'WeeklyChartsDataFrame.csv')

# %%
class MoviePage():
  def __init__(self, release, url_sfx):
    self.prefix = 'https://www.boxofficemojo.com/'
    self.name = release
    self.url_sfx = self.url_clean(url_sfx)
    self.gross_pattern  = re.compile(r'.+(mojo-performance-summary-table$)')
    self.budget_pattern  = re.compile(r'Budget')
    self.mpaa_pattern  = re.compile(r'MPAA')
    self.genre_pattern  = re.compile(r'Genres')
    self.ser = pd.Series(dtype=object)

  def __repr__(self):
    return(f'{self.name} has a url of {self.url_sfx}')

  def url_clean(self, sfx):
    clean_url = sfx.split('?')
    return clean_url[0]

  def crawl(self):
    gross_list = []
    time.sleep(randint(2, 4))
    page = requests.get(self.prefix + self.url_sfx,
                        headers={'User-Agent': 'Mozilla/5.0'})
    soup = bs(page.text, 'lxml')
    self.ser['Budget'] = self.get_budget(soup)
    self.ser['MPAA'] = self.get_mpaa(soup)
    self.ser['Genre'] = self.get_genre(soup)
    gross_list = self.get_gross(soup)
    self.ser['D.Gross'] = gross_list[0]
    self.ser['I.Gross'] = gross_list[1]
    self.ser['Total Gross'] = gross_list[2]

  def get_budget(self, soup):
    try:
      budget = soup.find(text=self.budget_pattern).next_element
      budget_amount = int(re.sub('[$,]', '', budget.text))
    except AttributeError:
      budget_amount = np.nan
    return(budget_amount)
  
  def get_mpaa(self, soup):
    try:
      mpaa = soup.find(text=self.mpaa_pattern).next_element.text
    except AttributeError:
      return('attrerror')
    return(mpaa) 
  
  def get_genre(self, soup):
    try:
      genre = soup.find(text=self.genre_pattern).next_element.text.split()
      return(genre)
    except AttributeError:
      return('attrerror')

  def get_gross(self, soup):
    try:
      # grab gross class
      grosses =soup.find(class_=movie.gross_pattern)
      money_pattern = re.compile('\$[\d+,]+|–')
      # find text matching money pattern
      grosses = grosses.find_all('span', text=money_pattern)
      # iterate through text, replacing - and removing $,
      for idx, gross in enumerate(grosses):
        if gross.text == '–':
          grosses[idx] = np.nan
          continue
        else:
          grosses[idx] = int(re.sub('[$,]', '', gross.text))
    except AttributeError:
      grosses = [np.nan, np.nan, np.nan]
    return(grosses)

# %% [markdown]
# ###MoviePage.url_clean() alternative
# splitting the string at a ? should be fine because of the way ?'s are treated in html. Still, it seems a bit arbitrary. We could instead use a REGEX to identify the part we want, instead of looking for the part we do not.

# %%
#insert REGEX here
# /rl\d*/$

# %% [markdown]
# #Aggregate Weekly Performances

# %%
header = {'User-Agent': 'Mozilla/5.0'}
WeeklyPage = WeeklyCharts(2022.15)
WeeklyPage.crawl()
WeeklyPage.save_final_df()
print('Ding!')
# Out:
# breaktime!

# %%
url_df = pd.DataFrame.from_dict(WeeklyPage.movie_dict, orient='index')

# %%
url_df.to_csv('Movie_url_list.csv')

# %% [markdown]
# #Movie Page
# Aggregate each movie's attributes and performance.

# %%
#load url_list
df = pd.read_csv('Movie_url_list.csv')
# Transpose
movie_dict = df.set_index('Rank').T.to_dict('records')
movie_dict = movie_dict[0]
movie_df = pd.DataFrame()

# %%
# loop through movie dict, creating Series objects and appending to DataFrame
for idx, movie in enumerate(movie_dict):
  movie = MoviePage(movie, movie_dict[movie])
  movie.crawl()
  movie_df[movie.name] = movie.ser

movie_df.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   """
#         Star Wars: Episode IX - The Rise of Skywalker  \
# Budget                                      275000000
# MPAA                                            PG-13
# Genre            [Action, Adventure, Fantasy, Sci-Fi]
# D.Gross                                     515202542
# I.Gross                                     558941706
#
#                       Jumanji: The Next Level      Little Women  \
# Budget                              125000000          40000000
# MPAA                                    PG-13                PG
# Genre    [Action, Adventure, Comedy, Fantasy]  [Drama, Romance]
# D.Gross                             320314960         108101214
# I.Gross                             479744747         108500000
#
#                                                  Frozen II         The Grudge  \
# Budget                                           150000000           10000000
# MPAA                                                    PG                  R
# Genre    [Adventure, Animation, Comedy, Family, Fantasy...  [Fantasy, Horror]
# D.Gross                                          477373578           21221803
# I.Gross                                          972653355           28289516
#
#                                          Spies in Disguise  \
# Budget                                           100000000
# MPAA                                                    PG
# Genre    [Action, Adventure, Animation, Comedy, Family,...
# D.Gross                                           66757013
# I.Gross                                          104859751
#
#                                         Knives Out                Uncut Gems  \
# Budget                                    40000000                  19000000
# MPAA                                         PG-13                         R
# Genre    [Comedy, Crime, Drama, Mystery, Thriller]  [Crime, Drama, Thriller]
# D.Gross                                  165363234                  50023780
# I.Gross                                  146242347                       NaN
#
#                   Bombshell                                       Cats  ...  \
# Budget             32000000                                   95000000  ...
# MPAA                      R                                         PG  ...
# Genre    [Biography, Drama]  [Comedy, Drama, Family, Fantasy, Musical]  ...
# D.Gross            31762808                                   27166770  ...
# I.Gross            29641586                                   46666578  ...
#
#         The Unbearable Weight of Massive Talent Y cómo es él?           Vivo  \
# Budget                                      NaN           NaN            NaN
# MPAA                                          R         PG-13      attrerror
# Genre         [Action, Comedy, Crime, Thriller]      [Comedy]  [Documentary]
# D.Gross                                16831956       1284711         351494
# I.Gross                                 5312159       3125233         315458
#
#              Petite Maman                    The Duke         Unplugging  \
# Budget                NaN                         NaN                NaN
# MPAA                   PG                           R                  R
# Genre    [Drama, Fantasy]  [Biography, Comedy, Drama]  [Comedy, Romance]
# D.Gross            362934                      587819              20500
# I.Gross           1097421                    11165215              13795
#
#            Charlotte Hit the Road Take Me to the River: New Orleans  \
# Budget           NaN          NaN                               NaN
# MPAA       attrerror    attrerror                         attrerror
# Genre    [Animation]      [Drama]                     [Documentary]
# D.Gross        17419        74609                             13619
# I.Gross          NaN       303877                               NaN
#
#         Stanleyville
# Budget           NaN
# MPAA       attrerror
# Genre       [Comedy]
# D.Gross         2137
# I.Gross          NaN
#
# [5 rows x 906 columns]

# %%
movie_df.T.head()
# Out:
#                                                   Budget   MPAA  \
# Star Wars: Episode IX - The Rise of Skywalker  275000000  PG-13
# Jumanji: The Next Level                        125000000  PG-13
# Little Women                                    40000000     PG
# Frozen II                                      150000000     PG
# The Grudge                                      10000000      R
#
#                                                                                            Genre  \
# Star Wars: Episode IX - The Rise of Skywalker               [Action, Adventure, Fantasy, Sci-Fi]
# Jumanji: The Next Level                                     [Action, Adventure, Comedy, Fantasy]
# Little Women                                                                    [Drama, Romance]
# Frozen II                                      [Adventure, Animation, Comedy, Family, Fantasy...
# The Grudge                                                                     [Fantasy, Horror]
#
#                                                  D.Gross    I.Gross  \
# Star Wars: Episode IX - The Rise of Skywalker  515202542  558941706
# Jumanji: The Next Level                        320314960  479744747
# Little Women                                   108101214  108500000
# Frozen II                                      477373578  972653355
# The Grudge                                      21221803   28289516
#
#                                               Total Gross
# Star Wars: Episode IX - The Rise of Skywalker  1074144248
# Jumanji: The Next Level                         800059707
# Little Women                                    216601214
# Frozen II                                      1450026933
# The Grudge                                       49511319

# %%
new_frame = movie_df.copy()

# %%
nf_transpose = new_frame.T

# %%
nf_transpose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 906 entries, Star Wars: Episode IX - The Rise of Skywalker to Stanleyville
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Budget       80 non-null     object
#  1   MPAA         906 non-null    object
#  2   Genre        906 non-null    object
#  3   D.Gross      887 non-null    object
#  4   I.Gross      617 non-null    object
#  5   Total Gross  906 non-null    object
# dtypes: object(6)
# memory usage: 81.8+ KB

# %%
nf_transpose.head(10)
# Out:
#                                                   Budget   MPAA  \
# Star Wars: Episode IX - The Rise of Skywalker  275000000  PG-13
# Jumanji: The Next Level                        125000000  PG-13
# Little Women                                    40000000     PG
# Frozen II                                      150000000     PG
# The Grudge                                      10000000      R
# Spies in Disguise                              100000000     PG
# Knives Out                                      40000000  PG-13
# Uncut Gems                                      19000000      R
# Bombshell                                       32000000      R
# Cats                                            95000000     PG
#
#                                                                                            Genre  \
# Star Wars: Episode IX - The Rise of Skywalker               [Action, Adventure, Fantasy, Sci-Fi]
# Jumanji: The Next Level                                     [Action, Adventure, Comedy, Fantasy]
# Little Women                                                                    [Drama, Romance]
# Frozen II                                      [Adventure, Animation, Comedy, Family, Fantasy...
# The Grudge                                                                     [Fantasy, Horror]
# Spies in Disguise                              [Action, Adventure, Animation, Comedy, Family,...
# Knives Out                                             [Comedy, Crime, Drama, Mystery, Thriller]
# Uncut Gems                                                              [Crime, Drama, Thriller]
# Bombshell                                                                     [Biography, Drama]
# Cats                                                   [Comedy, Drama, Family, Fantasy, Musical]
#
#                                                  D.Gross    I.Gross  \
# Star Wars: Episode IX - The Rise of Skywalker  515202542  558941706
# Jumanji: The Next Level                        320314960  479744747
# Little Women                                   108101214  108500000
# Frozen II                                      477373578  972653355
# The Grudge                                      21221803   28289516
# Spies in Disguise                               66757013  104859751
# Knives Out                                     165363234  146242347
# Uncut Gems                                      50023780        NaN
# Bombshell                                       31762808   29641586
# Cats                                            27166770   46666578
#
#                                               Total Gross
# Star Wars: Episode IX - The Rise of Skywalker  1074144248
# Jumanji: The Next Level                         800059707
# Little Women                                    216601214
# Frozen II                                      1450026933
# The Grudge                                       49511319
# Spies in Disguise                               171616764
# Knives Out                                      311605581
# Uncut Gems                                       50023780
# Bombshell                                        61404394
# Cats                                             73833348

# %%
nf_transpose.to_csv('movie_performance.csv')
