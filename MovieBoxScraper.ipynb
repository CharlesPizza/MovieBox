# %%
import re
import requests
import lxml
import pandas as pd
import time
import numpy as np
from random import randint
from bs4 import BeautifulSoup as bs

# %%
class WeeklyCharts():
  def __init__(self, stop):
    self.prefix = 'https://www.boxofficemojo.com/weekly/'
    self.date = 2020.00
    self.stop = stop
    self.string_url = ''
    self.movie_dict = {}
    self.string_sfx = ''
    self.final_df = pd.DataFrame()

  def string_suff(self):
    # URL suffix format is a 2 digit year, W, 2 digit week; starting at 20W01
    # Weeks start on friday. Converted to a float for ease of calculations
    string_sfx = str('{:.2f}'.format(self.date))
    string_sfx = string_sfx.replace('.','W')
    self.string_sfx = string_sfx
    return (string_sfx + '/')

  def next_page(self):
    if self.date == self.stop:
      return (self.stop)
    elif round(self.date % 1, ndigits=2) == 0.52:
      self.date += 1
      self.date -= 0.51
    else:
      self.date += .01
    self.string_url = self.prefix + self.string_suff()
    return self.string_url

  def crawl(self):
    while self.date < self.stop:
      time.sleep(randint(1, 3))
      page = requests.get(self.next_page(), headers=header)
      soup = bs(page.text, 'lxml')

      table = soup.table.children
      for i in table:
        movie_name = i.find('a').text
        movie_url = i.find('a')['href']
        if movie_name not in self.movie_dict.keys():
          self.movie_dict[movie_name] = movie_url

      df = pd.read_html(page.text)
      df = df[0]
      df['YRWK'] = '{:2f}'.format(self.date)
      self.final_df = pd.concat([self.final_df, df])
      
  def save_final_df(self):
    self.final_df.to_csv(f'WeeklyChartsDataFrame.csv')

# %%
class MoviePage():
  def __init__(self, release, url_sfx):
    self.prefix = 'https://www.boxofficemojo.com/'
    self.name = release
    self.url_sfx = self.url_clean(url_sfx)
    self.gross_pattern  = re.compile(r'.+(mojo-performance-summary-table$)')
    self.budget_pattern  = re.compile(r'Budget')
    self.mpaa_pattern  = re.compile(r'MPAA')
    self.genre_pattern  = re.compile(r'Genres')
    self.ser = pd.Series(dtype=object)

  def __repr__(self):
    return(f'{self.name} has a url of {self.url_sfx}')

  def url_clean(self, sfx):
    clean_url = sfx.split('?')
    return clean_url[0]

  def crawl(self):
    gross_list = []
    time.sleep(randint(2, 4))
    page = requests.get(self.prefix + self.url_sfx,
                        headers={'User-Agent': 'Mozilla/5.0'})
    soup = bs(page.text, 'lxml')
    self.ser['Budget'] = self.get_budget(soup)
    self.ser['MPAA'] = self.get_mpaa(soup)
    self.ser['Genre'] = self.get_genre(soup)
    gross_list = self.get_gross(soup)
    self.ser['D.Gross'] = gross_list[0]
    self.ser['I.Gross'] = gross_list[1]
    self.ser['Total Gross'] = gross_list[2]

  def get_budget(self, soup):
    try:
      budget = soup.find(text=self.budget_pattern).next_element
      budget_amount = int(re.sub('[$,]', '', budget.text))
    except AttributeError:
      budget_amount = np.nan
    return(budget_amount)
  
  def get_mpaa(self, soup):
    try:
      mpaa = soup.find(text=self.mpaa_pattern).next_element.text
    except AttributeError:
      mpaa = self.crawl_deeper(soup)
    return mpaa.strip()
  
  def get_genre(self, soup):
    try:
      genre = soup.find(text=self.genre_pattern).next_element.text.split()
      return(genre)
    except AttributeError:
      return('attrerror')

  def get_gross(self, soup):
    try:
      # grab gross class
      grosses =soup.find(class_=movie.gross_pattern)
      money_pattern = re.compile('\$[\d+,]+|–')
      # find text matching money pattern
      grosses = grosses.find_all('span', text=money_pattern)
      # iterate through text, replacing - and removing $,
      for idx, gross in enumerate(grosses):
        if gross.text == '–':
          grosses[idx] = np.nan
          continue
        else:
          grosses[idx] = int(re.sub('[$,]', '', gross.text))
    except AttributeError:
      grosses = [np.nan, np.nan, np.nan]
    return(grosses)

  def crawl_deeper(self, soup):
    title_pattern = re.compile('.*(mojo-title-link).*')
    title_link = soup.find(class_=title_pattern)
    # href section we want is before ?ref : /title/tt0000000/?ref
    try:
      title_sfx, _ = title_link.get('href').split('?')
    except AttributeError:
      return('Not Rated')
    page = requests.get('https://pro.imdb.com/' + title_sfx, headers={'User-Agent': 'Mozilla/5.0'})
    soup = bs(page.text, 'lxml')
    rating = soup.find(id='certificate')
    if self.ser['Budget'] == np.nan:
      deeper = IMDB_crawl(title_sfx)
      self.ser['Budget'] = deeper.get_budget()
    try:
      return(rating.text)
    except AttributeError:
      return('Not Rated')

# %%
class IMDB_crawl():
  def __init__(self, url_sfx):
    self.url_prefix = 'https://www.imdb.com/'
    self.url_sfx = url_sfx
    self.url = self.url_prefix + self.url_sfx
  def get_budget(self):
    page = requests.get(self.url, headers={'User-Agent': 'Mozilla/5.0'})
    soup = bs(page.text, 'lxml')
    try:
      budget_element = soup.find(attrs={'data-testid':'title-boxoffice-section'})
      budget = budget_element.find(text=re.compile(r'Budget')).children.span.text
      budget = self.clean_money(budget)
      return budget
    except AttributeError:
      return(np.nan)
  def clean_money(self, money_string):
    money_string = re.sub('[$,a-z]', '', money_string)
    return(money_string)

# %% [markdown]
# ###MoviePage.url_clean() alternative
# splitting the string at a ? should be fine because of the way ?'s are treated in html. Still, it seems a bit arbitrary. We could instead use a REGEX to identify the part we want, instead of looking for the part we do not.

# %%
#insert REGEX here
# /rl\d+/$

# %% [markdown]
# #Aggregate Weekly Performances

# %%
header = {'User-Agent': 'Mozilla/5.0'}
WeeklyPage = WeeklyCharts(2022.15)
WeeklyPage.crawl()
WeeklyPage.save_final_df()
# Out:
# breaktime!

# %%
url_df = pd.DataFrame.from_dict(WeeklyPage.movie_dict, orient='index')

# %%
url_df.to_csv('Movie_url_list.csv')

# %% [markdown]
# #Movie Page
# Aggregate each movie's attributes and performance.

# %%
#load url_list
df = pd.read_csv('Movie_url_list.csv')
# Transpose
movie_dict = df.set_index('Rank').T.to_dict('records')
movie_dict = movie_dict[0]
movie_df = pd.DataFrame()

# %%
# loop through movie dict, creating Series objects and appending to DataFrame
series_dict = {}
for idx, movie in enumerate(movie_dict):
  movie = MoviePage(movie, movie_dict[movie])
  movie.crawl()
  series_dict[movie.name] = movie.ser
# I think a better solution to series_dict would be a numpy array/records
  print(movie.name)
# Out:
# Star Wars: Episode IX - The Rise of Skywalker
# Jumanji: The Next Level
# Little Women
# Frozen II
# The Grudge
# Spies in Disguise
# Knives Out
# Uncut Gems
# Bombshell
# Cats
# Richard Jewell
# Ford v Ferrari
# A Beautiful Day in the Neighborhood
# Queen & Slim
# Parasite
# 1917
# Ip Man 4: The Finale
# 21 Bridges
# Jojo Rabbit
# A Hidden Life
# Mystify: Michael Hutchence
# Dark Waters
# Merci pour tout
# Midway
# Black Christmas
# Doctor Who Live Q&A And Screening
# Harriet
# Playing with Fire
# Joker
# Maleficent: Mistress of Evil
# Just Mercy
# Fantastic Fungi
# No Safe Spaces
# Pain and Glory
# The Good Liar
# The Song of Names
# Zombieland: Double Tap
# 63 Up
# Cunningham
# Ashfall
# Clemency
# Invisible Life
# Honey Boy
# The Lighthouse
# Charlie's Angels
# Waves
# Doctor Sleep
# Once Upon a Time... In Hollywood
# Countdown
# Advocate
# Judy
# The White Sheik
# Branagh Theatre Live: The Winter's Tale
# Playmobil: The Movie
# American Dharma
# Synonyms
# Les Misérables: The Staged Concert
# Midnight Family
# The Kingmaker
# Linda Ronstadt: The Sound of My Voice
# Varda by Agnès
# Recorder: The Marion Stokes Project
# Downtown 81
# Promare
# Maiden
# The Woman Who Loves Giraffes
# Aquarela
# Hustlers
# Sympathy for the Devil
# A Bigger Splash
# Frankie
# Tremors
# Christ Stopped at Eboli
# The Disappearance of My Mother
# Redoubt
# Stuffed
# Give Me Liberty
# Be Natural: The Untold Story of Alice Guy-Blaché
# By the Grace of God
# Chained for Life
# Shooting the Mafia
# Like a Boss
# Underwater
# Weathering with You
# Sarileru Neekevvaru
# Chhapaak
# Les Misérables
# Three Christs
# Citizen K
# Matthias & Maxime
# Little Joe
# Duet for Cannibals
# Light from Light
# Ága
# Kind Hearts and Coronets
# A German Youth
# Bad Boys for Life
# Dolittle
# An American in Paris
# Blind Eyes Opened
# VHYes
# Lore
# The Wave
# Blood Widow
# Play the Flute
# The Wonderland
# The Hottest August
# The Gliksmans
# Millennium Actress
# Spiral Farm
# Hyenas
# The Gentlemen
# The Turning
# The Last Full Measure
# Panga
# Color Out of Space
# The Man Standing Next
# Zombi Child
# The Cave
# Honeyland
# The Perfect Race
# Chinese Portrait
# End of the Century
# Mr. Klein
# Gretel & Hansel
# The Rhythm Section
# 2020 Oscar Nominated Short Films
# Created Equal: Clarence Thomas in His Own Words
# The Assistant
# The Traitor
# Incitement
# José
# Beanpole
# Birds of Prey
# Jay and Silent Bob Reboot
# The Doors: Break On Thru - A Celebration Of Ray Manzarek
# Love Story
# The Lodge
# Come to Daddy
# After Parkland
# And Then We Danced
# Cane River
# Pandora and the Flying Dutchman
# Foosballers
# The Cordillera of Dreams
# Sonic the Hedgehog
# Fantasy Island
# The Photograph
# Downhill
# Patterns of Evidence: The Red Sea Miracle
# Portrait of a Lady on Fire
# Mafia Inc
# Ride Your Wave
# National Theater Live: Cyrano de Bergerac
# First Lady
# The Times of Bill Cunningham
# Enter the Fat Dragon
# Ordinary Love
# A Simple Wedding
# Buffaloed
# L'Innocente
# Olympic Dreams
# I Was at Home, But...
# Corpus Christi
# You Go to My Head
# Born to Be Wild
# A Beautiful Planet
# Under the Sea 3D
# Hubble
# Deep Sea
# The Load
# To the Arctic 3D
# Asako I & II
# Island of Lemurs: Madagascar
# The Call of the Wild
# Brahms: The Boy II
# My Hero Academia: Heroes Rising
# Impractical Jokers: The Movie
# My Boyfriend's Meds
# Emma.
# Seberg
# Once Were Brothers
# Come and See
# CatVideoFest 2020
# Premature
# Young Ahmed
# Vitalina Varela
# Just One More Kiss
# Balloon
# Goldie
# Edie
# Hai Tang Hong
# Space Station 3D
# The Invisible Man
# Greed
# Wendy
# The Whistlers
# Burden
# The Jesus Rolls
# Saint Frances
# Disappearance at Clifton Hill
# Lost in America
# Onward
# The Way Back
# Baaghi 3
# Tokyo Godfathers
# 14 Days, 12 Nights
# Extra Ordinary
# First Cow
# Hope Gap
# Nick Mason's Saucerful of Secrets: Live at the Roundhouse
# Bacurau
# The Booksellers
# The Burnt Orange Heresy
# Swallow
# Made in Hong Kong
# Sorry We Missed You
# The Wild Goose Lake
# Juvenile Delinquents
# Powerbomb
# King's Gambit
# Bloodshot
# I Still Believe
# The Hunt
# Riverdance 25th Anniversary Show
# Chal Mera Putt 2
# Heart of Africa
# Never Rarely Sometimes Always
# Human Nature
# The Roads Not Taken
# Straight Up
# Phoenix, Oregon
# Strike
# The Other Lamb
# Resistance
# True History of the Kelly Gang
# The Wretched
# How to Build a Girl
# Circles
# We Summon the Darkness
# The Trip to Greece
# Max Winslow and the House of Secrets
# Becky
# Unsubscribe
# Infamous
# Sometimes Always Never
# Sex and the Future
# The Fox Hunter
# Followed
# StarDog and TurboCat
# Miss Juneteenth
# Babyteeth
# The Last Tree
# The Transcendents
# Relic
# The Wandering Earth
# The Outpost
# The Truth
# Archive
# Bump Kowalski and the Ten Commandments
# Guest Artist
# Human Capital
# The Painted Bird
# The Rental
# The Big Ugly
# She Dies Tomorrow
# Summerland
# The Grizzlies
# What We Found
# Killer Raccoons! 2! Dark Christmas in the Dark!
# The Tax Collector
# Peninsula
# Made in Italy
# The SpongeBob Movie: Sponge on the Run
# Unhinged
# The Silencing
# Spree
# Sputnik
# The Bay of Silence
# I'll Take Your Dead
# In the Life of Music
# Words on Bathroom Walls
# Cut Throat City
# Tulsa
# Tesla
# The New Mutants
# Tenet
# Bill & Ted Face the Music
# The Personal History of David Copperfield
# The Eight Hundred
# Centigrade
# Still Here
# Made in Bangladesh
# My Brothers' Crossing
# The Broken Hearts Gallery
# Rent-A-Pal
# The Secrets We Keep
# Find Your Voice
# Fear Pharm
# Infidel
# Alone
# Follow Me
# The Nest
# The Way I See It
# Foster Boy
# Draupadi Unleashed
# Star Wars: Episode V - The Empire Strikes Back
# The Last Shift
# Shortcut
# Kajillionaire
# Ava
# On the Basis of Sex
# Leap
# Lie Exposed
# Ottolenghi and the Cakes of Versailles
# Dreaming Grand Avenue
# Hocus Pocus
# Possessor
# Save Yourselves!
# The Call
# Jiang Ziya
# A Call to Spy
# Heaven
# 12 Hour Shift
# Tar
# Neither Wolf Nor Dog
# The War with Grandpa
# Coco
# Yellow Rose
# The Wolf of Snow Hollow
# 100% Wolf
# Henchmen
# Pray: The Story of Patrick Peyton
# Honest Thief
# The Nightmare Before Christmas
# 2 Hearts
# Love and Monsters
# The Kid Detective
# Stevie Nicks 24 Karat Gold the Concert
# Lupin III: The First
# She Is the Ocean
# Counter Column
# Shithouse
# Twiceborn
# The Bra
# Mermaid in Paris
# The Shade Shepherd
# Benjamin the Elephant (2020)
# The Empty Man
# Monsters, Inc.
# After We Collided
# The Addams Family
# Synchronic
# Bang! Bang!
# Come Play
# Spell
# Alita: Battle Angel
# Let Him Go
# Toy Story
# True to the Game 2
# The Informer
# The Dark and the Wicked
# Kindred
# Freaky
# Guardians of the Galaxy
# Elf
# The Climb
# Fatman
# Come Away
# Ammonite
# The Croods: A New Age
# The Santa Clause
# Vanguard
# The Last Vermeer
# Buddy Games
# Fate/Stay Night: Heaven's Feel - III. Spring Song
# The Forgotten Carols
# National Lampoon's Christmas Vacation
# Frozen
# Always and Forever
# Embattled
# Stardust
# Last Call
# Amigo Skate, Cuba
# The Grinch
# Zappa
# Half Brothers
# All My Life
# Die Hard
# The Polar Express
# The Godfather: Part III
# Dear Santa
# Crock of Gold: A Few Rounds with Shane MacGowan
# Wonder Woman
# Wild Mountain Thyme
# Archenemy
# Farewell Amor
# Ip Man: Kung Fu Master
# Monster Hunter
# Fatale
# How the Grinch Stole Christmas
# The Muppet Christmas Carol
# Bolshoi Ballet: The Nutcracker
# It's a Wonderful Life
# Hunter Hunter
# The Rescue
# Parallel Policy
# Wonder Woman 1984
# News of the World
# Promising Young Woman
# Pinocchio
# A Christmas Story
# Solo Brathuke So Better
# The Dissident
# Alien
# Shadow in the Cloud
# Evergreen
# Jurassic World
# Some Kind of Heaven
# Average Joe
# Zombie Bro
# The Marksman
# The Emperor's New Groove
# American Skin
# Sing
# MLK/FBI
# Bloody Hell
# Mother to Earth
# Our Friend
# Wrong Turn
# No Man's Land
# Abominable
# Psycho Goreman
# About Hope
# The Little Things
# Groundhog Day
# Supernova
# Remember the Titans
# Earwig and the Witch
# The Night
# Tomato Red: Blood Money
# The Reckoning
# Little Fish
# Dara of Jasenovac
# Two of Us
# A Glitch in the Matrix
# Judas and the Black Messiah
# Land
# Minari
# The Mauritanian
# Willy's Wonderland
# A Writer's Odyssey
# The World to Come
# The Incredible 25th Year of Mitzi Bearclaw
# Skyfire
# Nomadland
# Blithe Spirit
# The Violent Heart
# End Game
# Abandoned: Angelique's Isle
# Elbow Grease
# Tom & Jerry: The Movie
# Crisis
# Safer at Home
# My Zoe
# The Vigil
# Raya and the Last Dragon
# Chaos Walking
# Boogie
# My Salinger Year
# Son
# No Place
# The Father
# Jathi Ratnalu
# Long Weekend
# Lamb of God: The Concert Film
# Dutch
# Come True
# Honeydew
# Stray
# The Courier
# City of Lies
# Dark State
# Godzilla vs. Kong
# Nobody
# Six Minutes to Midnight
# Mystery of the Kingdom of God
# Things Don't Stay Fixed
# First Signal
# The Unholy
# The Girl Who Believes in Miracles
# French Exit
# 2021 Oscar Nominated Short Films: Live Action
# Shiva Baby
# Blood Brothers: Civil War
# The Boonies
# Voyagers
# Held
# Moffie
# The Truffle Hunters
# Senior Moment
# Slalom
# In the Earth
# SAS: Red Notice
# Monday
# We Broke Up
# Gunda
# Bill Traylor: Chasing Ghosts
# Demon Slayer the Movie: Mugen Train
# Mortal Kombat
# Together Together
# Separation
# Scott Pilgrim vs. the World
# Four Good Days
# Limbo
# The Resort
# Cliff Walkers
# About Endlessness
# Endless Rain
# Wrath of Man
# Here Today
# Walking with Herb
# The Paper Tigers
# My Love
# Mission Stories
# Mainstream
# The Human Factor
# State Funeral
# The Unthinkable
# Spiral
# Those Who Wish Me Dead
# Finding You
# Profile
# Top Gun
# The Water Man
# The Djinn
# The Killing of Two Lovers
# La Piscine
# There Is No Evil
# Ghost Master
# The Perfect Candidate
# Dream Horse
# New Order
# Final Account
# The Dry
# Riders of Justice
# A Quiet Place Part II
# Cruella
# World War Z
# Funhouse
# The Conjuring: The Devil Made Me Do It
# Spirit Untamed
# Witnesses
# Undine
# Gully
# Hero Mode
# The Ladykillers
# All Light, Everywhere
# In the Heights
# Peter Rabbit 2: The Runaway
# Hitman's Wife's Bodyguard
# The House Next Door: Meet the Blacks 2
# Queen Bees
# 12 Mighty Orphans
# Children of the Sea
# Holler
# Final Frequency
# The Sparks Brothers
# Rita Moreno: Just a Girl Who Decided to Go for It
# Censor
# Summer of 85
# Truman & Tennessee: An Intimate Conversation
# Our Ladies
# Crack House of the Dead
# Sweat
# F9: The Fast Saga
# Zola
# Werewolves Within
# Lansky
# I Carry You with Me
# Gaia
# Le Cercle Rouge
# A Soldier's Story 2: Return from the Dead
# The Evil Next Door
# Felix and the Hidden Treasure
# The Boss Baby 2: Family Business
# The Forever Purge
# Summer of Soul (...Or, When the Revolution Could Not Be Televised)
# The God Committee
# First Date
# Lydia Lunch: The War Is Never Over
# Operation Portugal
# Black Widow
# The Loneliest Whale: The Search for 52
# Scales
# Casanova, Last Love
# Space Jam: A New Legacy
# Escape Room: Tournament of Champions
# Roadrunner: A Film About Anthony Bourdain
# Pig
# Once I Was Engaged
# Summertime
# Mama Weed
# How It Ends
# Rock Paper Scissors
# Old
# Snake Eyes
# Joe Bell
# Kaamelott: First Installment
# CatVideoFest 2021
# Ailey
# Settlers
# Mandibles
# Secret Agent Dingledorf and His Trusty Dog Splat
# Without Getting Killed or Caught
# Here After
# No Ordinary Man
# Can You Bring It: Bill T. Jones and D-Man in the Waters
# Victim of Love
# Jungle Cruise
# The Green Knight
# Stillwater
# Nine Days
# Lorelei
# Enemies of the State
# Never Gonna Snow Again
# Sabaya
# The Suicide Squad
# Swan Song
# John and the Hole
# Bring Your Own Brigade
# Even in Dreams
# Free Guy
# Don't Breathe 2
# Respect
# The Lost Leonardo
# Ema
# The Meaning of Hitler
# White as Snow
# The East
# PAW Patrol: The Movie
# The Protégé
# The Night House
# Reminiscence
# If I Can't Have Love, I Want Power
# Flag Day
# Demonic
# Cryptozoo
# Confetti
# Death Rider in the House of Vampires
# Candyman
# An Egg Rescue
# Together
# Raging Fire
# Escape from Mogadishu
# Ma Belle, My Beauty
# On Broadway
# Baking Up Love
# Shang-Chi and the Legend of the Ten Rings
# Tango Shalom
# Who You Think I Am
# Yakuza Princess
# We Need to Do Something
# The Year of the Everlasting Storm
# Malignant
# The Card Counter
# Show Me the Father
# After We Fell
# The Alpinist
# Small Engine Repair
# Language Lessons
# Mogul Mowgli
# Dating & New York
# Azor
# Cry Macho
# Copshop
# The Eyes of Tammy Faye
# Blue Bayou
# Ghost in the Shell
# The Nowhere Inn
# Wife of a Spy
# Little Girl
# Dear Evan Hansen
# Courageous
# I'm Your Man
# Breathless
# Storm Lake
# The Village Detective: a song cycle
# Venom: Let There Be Carnage
# The Addams Family 2
# The Many Saints of Newark
# God's Not Dead: We the People
# Titane
# The Jesus Music
# Old Henry
# Falling for Figaro
# In Balanchine's Classroom
# Mayday
# No Time to Die
# Lamb
# My Country, My Parents
# Mass
# Possession
# Golden Voices
# Ascension
# Halloween Kills
# The Last Duel
# Bergman Island
# Monster Family 2
# Hard Luck Love Song
# Introducing, Selma Blair
# Luzzu
# Dune
# Ron's Gone Wrong
# The French Dispatch
# Becoming Cousteau
# Learning to Live Together: The Return of Mad Dogs & Englishmen
# 13 Fanboy
# The Laws of the Universe: The Age of Elohim
# Minyan
# My Hero Academia: World Heroes' Mission
# Last Night in Soho
# Antlers
# Ghostbusters
# A Mouthful of Air
# Heart of Champions
# The Souvenir: Part II
# Only the Animals
# Cicada
# Labyrinth of Cinema
# Eternals
# Clifford the Big Red Dog
# Spencer
# Sooryavanshi
# Christmas vs. The Walters
# The Beta Test
# Love It Was Not
# Dear Rider: The Jake Burton Story
# Belfast
# Anita
# Julia
# What Do We See When We Look at the Sky?
# Ghostbusters: Afterlife
# Encanto
# King Richard
# House of Gucci
# Resident Evil: Welcome to Raccoon City
# India Sweets and Spices
# C'mon C'mon
# The Battle at Lake Changjin
# For the Love of Money
# The First Wave
# Kurt Vonnegut: Unstuck in Time
# The Youngest Evangelist
# Bad Luck Banging or Loony Porn
# I Was a Simple Man
# The Feast
# The Incredibly True Adventure of Two Girls in Love
# Christmas with the Chosen: The Messengers
# Licorice Pizza
# Aline
# Drive My Car
# True to the Game 3
# Benedetta
# Wolf
# Tadap
# Try Harder!
# Flee
# The Scary of Sixty-First
# Writing with Fire
# Torn
# West Side Story
# National Champions
# Red Rocket
# France
# Agnes
# Spider-Man: No Way Home
# Sing 2
# The Matrix Resurrections
# Nightmare Alley
# The King's Man
# The Novice
# Harper
# Nights of Cabiria
# The Velvet Queen
# American Underdog
# A Journal for Jordan
# '83
# Parallel Mothers
# Memoria
# Jockey
# The 355
# See for Me
# Scream
# Belle
# Who We Are: A Chronicle of Racism in America
# The Conversation
# Italian Studies
# Alter Ego
# The Pink Cloud
# Redeeming Love
# The King's Daughter
# The Tiger Rising
# Shortbus
# Compartment Number 6
# Simple Passion
# The Beatles: Get Back - The Rooftop Concert
# Clean
# Gamestop: Rise of the Players
# Sundown
# Poly Styrene: I Am a Cliché
# Brighton 4th
# A Taste of Hunger
# Jackass Forever
# Moonfall
# The Wolf and the Lion
# The Worst Person in the World
# Only Fools Rush In
# Lingui
# Death on the Nile
# Marry Me
# Blacklight
# Water Gate Bridge
# Catch the Fair One
# Fabian: Going to the Dogs
# Indemnity
# Uncharted
# Dog
# The Cursed
# Too Cool to Kill
# Strawberry Mansion
# Ted K
# The Automat
# A Banquet
# Studio 666
# Cyrano
# The Godfather
# 2022 Oscar Nominated Short Films: Live Action/2022 Oscar Nominated Short Films: Animation/2022 Oscar Nominated Short Films: Documentary
# Butter
# The Burning Sea
# The Batman
# Gangubai Kathiawadi
# After Yang
# Great Freedom
# Huda's Salon
# Adventures in Success
# BTS Permission to Dance on Stage - Seoul: Live Viewing
# Radhe Shyam
# Tyson's Run
# Gold
# All My Friends Hate Me
# I Am Here
# The Cherry Bushido
# The Servant
# I've Heard the Mermaids Singing
# Ultrasound
# Jujutsu Kaisen 0: The Movie
# X
# The Outfit
# The Kashmir Files
# Umma
# Alice
# Jane by Charlotte
# Ahed's Knee
# Laleh Drive
# The Torch
# The Lost City
# RRR
# Infinite Storm
# Everything Everywhere All at Once
# You Are Not My Mother
# Mothering Sunday
# Bronco Bullfrog
# Stunt Rock
# Morbius
# The Contractor
# Selena
# You Won't Be Alone
# Waterman
# The Rose Maker
# Barbarians
# Sonic the Hedgehog 2
# Ambulance
# Father Stu
# UFC 273: Volkanovski vs the Korean Zombie
# Inland Empire
# Cow
# Fantastic Beasts: The Secrets of Dumbledore
# K.G.F: Chapter 2
# Dual
# Paris, 13th District
# We're All Going to the World's Fair
# Mississippi Masala
# The Tale of King Crab
# The Bad Guys
# The Northman
# The Unbearable Weight of Massive Talent
# Y cómo es él?
# Vivo
# Petite Maman
# The Duke
# Unplugging
# Charlotte
# Hit the Road
# Take Me to the River: New Orleans
# Stanleyville

# %%
movie_df = pd.concat([movie_df, pd.DataFrame.from_dict(series_dict)])

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Budget to Total Gross
# Columns: 906 entries, Star Wars: Episode IX - The Rise of Skywalker to Stanleyville
# dtypes: object(906)
# memory usage: 42.5+ KB

# %%
movie_df = movie_df.T

# %%
movie_df = movie_df.astype({'Budget':'float64', 'D.Gross':'float64', 'I.Gross':'float64', 'Total Gross':'float64'})

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 906 entries, Star Wars: Episode IX - The Rise of Skywalker to Stanleyville
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Budget       80 non-null     float64
#  1   MPAA         906 non-null    object
#  2   Genre        906 non-null    object
#  3   D.Gross      887 non-null    float64
#  4   I.Gross      617 non-null    float64
#  5   Total Gross  906 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 81.8+ KB

# %%
movie_df.head()
# Out:
#                                                     Budget   MPAA  \
# Star Wars: Episode IX - The Rise of Skywalker  275000000.0  PG-13
# Jumanji: The Next Level                        125000000.0  PG-13
# Little Women                                    40000000.0     PG
# Frozen II                                      150000000.0     PG
# The Grudge                                      10000000.0      R
#
#                                                                                            Genre  \
# Star Wars: Episode IX - The Rise of Skywalker               [Action, Adventure, Fantasy, Sci-Fi]
# Jumanji: The Next Level                                     [Action, Adventure, Comedy, Fantasy]
# Little Women                                                                    [Drama, Romance]
# Frozen II                                      [Adventure, Animation, Comedy, Family, Fantasy...
# The Grudge                                                                     [Fantasy, Horror]
#
#                                                    D.Gross      I.Gross  \
# Star Wars: Episode IX - The Rise of Skywalker  515202542.0  558941706.0
# Jumanji: The Next Level                        320314960.0  479744747.0
# Little Women                                   108101214.0  108500000.0
# Frozen II                                      477373578.0  972653355.0
# The Grudge                                      21221803.0   28289516.0
#
#                                                 Total Gross
# Star Wars: Episode IX - The Rise of Skywalker  1.074144e+09
# Jumanji: The Next Level                        8.000597e+08
# Little Women                                   2.166012e+08
# Frozen II                                      1.450027e+09
# The Grudge                                     4.951132e+07

# %%
new_frame = movie_df.copy()

# %%
nf_transpose = new_frame.T

# %%
nf_transpose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, Budget to Total Gross
# Columns: 906 entries, Star Wars: Episode IX - The Rise of Skywalker to Stanleyville
# dtypes: object(906)
# memory usage: 42.7+ KB

# %% [markdown]
# Instantly, we see an issue. Our budget column only reported 80 non-null counts. Budget is one of the most important data instances we could have sequestered. We will need to investigate this.

# %%
nf_transpose.head(10)
# Out:
#             Star Wars: Episode IX - The Rise of Skywalker  \
# Budget                                        275000000.0
# MPAA                                                PG-13
# Genre                [Action, Adventure, Fantasy, Sci-Fi]
# D.Gross                                       515202542.0
# I.Gross                                       558941706.0
# Total Gross                                  1074144248.0
#
#                           Jumanji: The Next Level      Little Women  \
# Budget                                125000000.0        40000000.0
# MPAA                                        PG-13                PG
# Genre        [Action, Adventure, Comedy, Fantasy]  [Drama, Romance]
# D.Gross                               320314960.0       108101214.0
# I.Gross                               479744747.0       108500000.0
# Total Gross                           800059707.0       216601214.0
#
#                                                      Frozen II  \
# Budget                                             150000000.0
# MPAA                                                        PG
# Genre        [Adventure, Animation, Comedy, Family, Fantasy...
# D.Gross                                            477373578.0
# I.Gross                                            972653355.0
# Total Gross                                       1450026933.0
#
#                     The Grudge  \
# Budget              10000000.0
# MPAA                         R
# Genre        [Fantasy, Horror]
# D.Gross             21221803.0
# I.Gross             28289516.0
# Total Gross         49511319.0
#
#                                              Spies in Disguise  \
# Budget                                             100000000.0
# MPAA                                                        PG
# Genre        [Action, Adventure, Animation, Comedy, Family,...
# D.Gross                                             66757013.0
# I.Gross                                            104859751.0
# Total Gross                                        171616764.0
#
#                                             Knives Out  \
# Budget                                      40000000.0
# MPAA                                             PG-13
# Genre        [Comedy, Crime, Drama, Mystery, Thriller]
# D.Gross                                    165363234.0
# I.Gross                                    146242347.0
# Total Gross                                311605581.0
#
#                            Uncut Gems           Bombshell  \
# Budget                     19000000.0          32000000.0
# MPAA                                R                   R
# Genre        [Crime, Drama, Thriller]  [Biography, Drama]
# D.Gross                    50023780.0          31762808.0
# I.Gross                           NaN          29641586.0
# Total Gross                50023780.0          61404394.0
#
#                                                   Cats  ...  \
# Budget                                      95000000.0  ...
# MPAA                                                PG  ...
# Genre        [Comedy, Drama, Family, Fantasy, Musical]  ...
# D.Gross                                     27166770.0  ...
# I.Gross                                     46666578.0  ...
# Total Gross                                 73833348.0  ...
#
#             The Unbearable Weight of Massive Talent Y cómo es él?  \
# Budget                                          NaN           NaN
# MPAA                                              R         PG-13
# Genre             [Action, Comedy, Crime, Thriller]      [Comedy]
# D.Gross                                  18229696.0     1341918.0
# I.Gross                                   5715546.0     3125233.0
# Total Gross                              23945242.0     4467151.0
#
#                       Vivo      Petite Maman                    The Duke  \
# Budget                 NaN               NaN                         NaN
# MPAA             Not Rated                PG                           R
# Genre        [Documentary]  [Drama, Fantasy]  [Biography, Comedy, Drama]
# D.Gross           351494.0          580776.0                   1001474.0
# I.Gross           315458.0         1097421.0                  11097404.0
# Total Gross       666952.0         1678197.0                  12098878.0
#
#                     Unplugging    Charlotte Hit the Road  \
# Budget                     NaN          NaN          NaN
# MPAA                         R    Not Rated    Not Rated
# Genre        [Comedy, Romance]  [Animation]      [Drama]
# D.Gross                20500.0      18520.0      91753.0
# I.Gross                13795.0          NaN     303877.0
# Total Gross            34295.0      18520.0     395630.0
#
#             Take Me to the River: New Orleans Stanleyville
# Budget                                    NaN          NaN
# MPAA                                Not Rated    Not Rated
# Genre                           [Documentary]     [Comedy]
# D.Gross                               14631.0       2137.0
# I.Gross                                   NaN          NaN
# Total Gross                           14631.0       2137.0
#
# [6 rows x 906 columns]

# %%
nf_transpose.to_csv('movie_performance.csv')
